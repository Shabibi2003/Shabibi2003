# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\YOUSUF SHABIBI\Downloads\bank+marketing\bank-additional\bank-additional\bank-additional.csv", delimiter=';')

# %%
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df.tail()
# Out:
#       age         job  marital    education default housing loan    contact  \
# 4114   30      admin.  married     basic.6y      no     yes  yes   cellular
# 4115   39      admin.  married  high.school      no     yes   no  telephone
# 4116   27     student   single  high.school      no      no   no   cellular
# 4117   58      admin.  married  high.school      no      no   no   cellular
# 4118   34  management   single  high.school      no     yes   no   cellular
#
#      month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 4114   jul         thu  ...         1    999         0  nonexistent
# 4115   jul         fri  ...         1    999         0  nonexistent
# 4116   may         mon  ...         2    999         1      failure
# 4117   aug         fri  ...         1    999         0  nonexistent
# 4118   nov         wed  ...         1    999         0  nonexistent
#
#      emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
df.iloc[0]
# Out:
# age                        30
# job               blue-collar
# marital               married
# education            basic.9y
# default                    no
# housing                   yes
# loan                       no
# contact              cellular
# month                     may
# day_of_week               fri
# duration                  487
# campaign                    2
# pdays                     999
# previous                    0
# poutcome          nonexistent
# emp.var.rate             -1.8
# cons.price.idx         92.893
# cons.conf.idx           -46.2
# euribor3m               1.313
# nr.employed            5099.1
# y                          no
# Name: 0, dtype: object

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# Seperate the text columns 
obj_cols = df.select_dtypes(include='object').columns
print(obj_cols)
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'day_of_week', 'poutcome', 'y'],
#       dtype='object')

# %%
# separate the numeric columns
num_cols = df.select_dtypes(exclude='object').columns
print(num_cols)
# Out:
# Index(['age', 'duration', 'campaign', 'pdays', 'previous', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed'],
#       dtype='object')

# %%
# returns description of the data in the DataFrame 
df.describe()
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
df.describe(include='object')
# Out:
#            job  marital          education default housing  loan   contact  \
# count     4119     4119               4119    4119    4119  4119      4119
# unique      12        4                  8       3       3     3         2
# top     admin.  married  university.degree      no     yes    no  cellular
# freq      1012     2509               1264    3315    2175  3349      2652
#
#        month day_of_week     poutcome     y
# count   4119        4119         4119  4119
# unique    10           5            3     2
# top      may         thu  nonexistent    no
# freq    1378         860         3523  3668

# %%
df.describe(exclude='object')
# Out:
#                age     duration     campaign        pdays     previous  \
# count  4119.000000  4119.000000  4119.000000  4119.000000  4119.000000
# mean     40.113620   256.788055     2.537266   960.422190     0.190337
# std      10.313362   254.703736     2.568159   191.922786     0.541788
# min      18.000000     0.000000     1.000000     0.000000     0.000000
# 25%      32.000000   103.000000     1.000000   999.000000     0.000000
# 50%      38.000000   181.000000     2.000000   999.000000     0.000000
# 75%      47.000000   317.000000     3.000000   999.000000     0.000000
# max      88.000000  3643.000000    35.000000   999.000000     6.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx    euribor3m  nr.employed
# count   4119.000000     4119.000000    4119.000000  4119.000000  4119.000000
# mean       0.084972       93.579704     -40.499102     3.621356  5166.481695
# std        1.563114        0.579349       4.594578     1.733591    73.667904
# ...

# %%
# ploting the histogram of every features.
df.hist(figsize=(12,10),color='blue')
plt.show()

# %%
for features in obj_cols:
    plt.figure(figsize=(5,5))
    sns.countplot(x=features, data=df)
    plt.title(f'Bar Plot of {features}')
    plt.xlabel(features)
    plt.ylabel('Count')
    plt.xticks(rotation=90) 
    plt.show()

# %%
# ploting box plot of every features (it also show the ourliers)
df.plot(kind='box',subplots= True, layout= (4,3),figsize= (10,10),color='green')
plt.show()

# %%
columns = df[['age','campaign','duration']]
Q1 = np.percentile(columns,25)  #25% of columns
Q3 = np.percentile(columns,75)

# IQR = Inter Quartile Range {Q3-Q1}
iqr = Q3-Q1

lower_limit = Q1 - 1.5 * iqr
upper_limit = Q3 + 1.5 * iqr

df[['age','campaign','duration']] = columns[(columns > lower_limit) & (columns < upper_limit)]

# %%
df.plot(kind='box',subplots = True, layout=(2,5),figsize= (15,12))
plt.show()

# in this plot the outliers is remove with the help of above expression

# %%
correlation = df.corr(numeric_only = True)
print(correlation)
# Out:
#                      age  duration  campaign     pdays  previous  \
# age             1.000000  0.014048 -0.014169 -0.043425  0.050931
# duration        0.014048  1.000000 -0.218111 -0.093694  0.094206
# campaign       -0.014169 -0.218111  1.000000  0.058742 -0.091490
# pdays          -0.043425 -0.093694  0.058742  1.000000 -0.587941
# previous        0.050931  0.094206 -0.091490 -0.587941  1.000000
# emp.var.rate   -0.019192 -0.063870  0.176079  0.270684 -0.415238
# cons.price.idx -0.000482 -0.013338  0.145021  0.058472 -0.164922
# cons.conf.idx   0.098135  0.045889  0.007882 -0.092090 -0.051420
# euribor3m      -0.015033 -0.067815  0.159435  0.301478 -0.458851
# nr.employed    -0.041936 -0.097339  0.161037  0.381983 -0.514853
#
#                 emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# age                -0.019192       -0.000482       0.098135  -0.015033
# duration           -0.063870       -0.013338       0.045889  -0.067815
# ...

# %%
correlation = correlation[abs(correlation)>= 0.9]
sns.heatmap(correlation,annot = True, cmap = 'Set3')
plt.show()

# %%
high_corr_cols = ['emp.var.rate','euribor3m','nr.employed']

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df1 = df.copy()

# %%
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df1.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df1.drop(high_corr_cols,inplace= True,axis = 1) # droping the highest correlation columns

# %%
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx', 'y'],
#       dtype='object')

# %%
df1.shape
# Out:
# (4119, 18)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Lb = LabelEncoder()  # used to convert the categarical labels into numeric values

# %%
df_encoded = df1.apply(Lb.fit_transform)

# %%
df_encoded
# Out:
#       age  job  marital  education  default  housing  loan  contact  month  \
# 0      12    1        1          2        0        2     0        0      6
# 1      21    7        2          3        0        0     0        1      6
# 2       7    7        1          3        0        2     0        1      4
# 3      20    7        1          2        0        1     1        1      4
# 4      29    0        1          6        0        2     0        0      7
# ...   ...  ...      ...        ...      ...      ...   ...      ...    ...
# 4114   12    0        1          1        0        2     2        0      3
# 4115   21    0        1          3        0        2     0        1      3
# 4116    9    8        2          3        0        0     0        0      6
# 4117   40    0        1          3        0        0     0        0      1
# 4118   16    4        2          3        0        2     0        0      7
#
#       day_of_week  duration  campaign  pdays  previous  poutcome  \
# ...

# %%
df_encoded['y']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4114    0
# 4115    0
# 4116    0
# 4117    0
# 4118    0
# Name: y, Length: 4119, dtype: int32

# %%
df_encoded['y'].value_counts()
# Out:
# y
# 0    3668
# 1     451
# Name: count, dtype: int64

# %%
X = df_encoded.drop('y',axis=1)  # X feature (independent variable)

# %%
y = df_encoded['y']   # dependent variable

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3089, 17)
# (1030, 17)
# (3089,)
# (1030,)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
def eval_model(y_test,y_prediction):
    accuracy = accuracy_score(y_test,y_prediction)
    print("Accuracy :",accuracy)
    
    cm = confusion_matrix(y_test,y_prediction)
    print("Confusion Matrix\n",cm)
    
    cl = classification_report(y_test,y_prediction)
    print("Classification Report: \n",cl)
    
def score(model):
    train_score = model.score(X_train,y_train)
    test_score = model.score(X_test,y_test)
    
    print("Training Score",train_score)
    print("Test Score",test_score)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %%
score(dt)
# Out:
# Training Score 0.9184202007122046
# Test Score 0.9097087378640777

# %%
y_pred_dt = dt.predict(X_test)

# %%
eval_model(y_test,y_pred_dt)
# Out:
# Accuracy : 0.9097087378640777
# Confusion Matrix
#  [[896  23]
#  [ 70  41]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       919
#            1       0.64      0.37      0.47       111
#
#     accuracy                           0.91      1030
#    macro avg       0.78      0.67      0.71      1030
# weighted avg       0.90      0.91      0.90      1030

# %%
from sklearn.tree import plot_tree

# %%
cn = ['no','yes']
fn = X_train.columns
print(fn)
print(cn)
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'cons.price.idx', 'cons.conf.idx'],
#       dtype='object')
# ['no', 'yes']

# %%
plot_tree(dt,class_names=cn,filled=True)
plt.show()

# %%
dt1 = DecisionTreeClassifier(criterion='entropy',max_depth=4,min_samples_split=15)
dt1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=15)

# %%
score(dt)
# Out:
# Training Score 0.9184202007122046
# Test Score 0.9097087378640777

# %%
y_pred_dt1 = dt1.predict(X_test)

# %%
eval_model(y_test,y_pred_dt1)
# Out:
# Accuracy : 0.9048543689320389
# Confusion Matrix
#  [[906  13]
#  [ 85  26]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       919
#            1       0.67      0.23      0.35       111
#
#     accuracy                           0.90      1030
#    macro avg       0.79      0.61      0.65      1030
# weighted avg       0.89      0.90      0.88      1030

# %%
plt.figure(figsize=(12,15))
plot_tree(dt1,class_names=cn,filled=True)
plt.show()
